# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
# 汉字字体，优先使用楷体，找不到则使用黑体
plt.rcParams['font.sans-serif'] = ['Kaitt', 'SimHei']    
# 正常显示负号
plt.rcParams['axes.unicode_minus'] = False

# %%
import os
from pathlib import Path
path = r"E:\课设4\data221204"
tools = os.listdir(path)
windows = {'冲压':7, '切磨端面':16, '加热':18, '半精锥面':6, '摩擦焊':6, '杆部抛光':6, '磨锁夹槽':5}
L_ind = {'冲压':6, '切磨端面':1015, '加热':2, '半精锥面':164, '摩擦焊':151, '杆部抛光':151, '磨锁夹槽':150}
centroids_all_machine = {}

# windows 是一样的，但是阈值是不一样的
for tool in tools:
    window = windows[tool]
    tool_path = path + "\\" + tool
    files = os.listdir(tool_path)
    l_ind = L_ind[tool]
    for file in files:
        # 只训练一个数据集
        ind = file.index('_')
        machine_name = tool + file[5:ind]
        if machine_name in centroids_all_machine:
            continue
        centroids_all_machine[machine_name] = 0
        files_path = tool_path + "\\" + file
        data = pd.read_csv(files_path) # //可以读取
        
        plt.plot(data['i'][50000:50050],"b-.o")
        plt.xticks([])
        plt.xlabel('时间ts')
        plt.ylabel('电流i')
        plt.title(machine_name)
        plt.show()
#         # l_ind = Get_lind(train_data['i'])
#         window_train_data = window_split(train_data['i'], window=window, l_ind=l_ind, mode='train')
#         # 进行k_means训练
#         centroids,assignments,sse = k_means_clust(window_train_data, num_clust=3, num_iter=5, dis_func=estimate_twf)
#         centroids_all_machine[machine_name] = centroids

#         # 画聚类中心图并保存
#         PlotCurWave(centroids, machine_name)

# %%
import os
from pathlib import Path
path = r"E:\课设4\correct_state"
tools = os.listdir(path)
L_ind = {}
for tool in tools:
    tool_path = path + "\\" + tool
    files = os.listdir(tool_path)
    for file in files:
        # centroids = centroids_all_machine[machine_name]
        files_path = tool_path + "\\" + file
        data = pd.read_csv(files_path) # //可以读取
        print(files_path)
        plt.plot(data['i'][150:200],"b-.o")
        plt.xlabel('时间ts')
        plt.ylabel('电流i')
        plt.title(files_path)
        # plt.savefig('./pictures/加热.jpg')
        # rect = plt.Rectangle((top_left_x, top_left_y), width, height, fill=False, edgecolor = 'red',linewidth=1)
        plt.show()
        # l_ind = 2:data_mark_dtw\加热\4.48.121-206_0511-0520.csv
        # 0.18 ~ 1.22s=64s的时间
# Out:
# E:\课设4\correct_state\冲压\2.19.125-61_0501-0510.csv
# E:\课设4\correct_state\冲压\2.20.125-61_0511-0520.csv
# E:\课设4\correct_state\冲压\2.21.125-61_0521-0530.csv
# E:\课设4\correct_state\冲压\2.22.125-61_0601-0610.csv
# E:\课设4\correct_state\冲压\2.23.125-61_0611-0620.csv
# E:\课设4\correct_state\冲压\2.24.125-61_0701-0710.csv
# E:\课设4\correct_state\冲压\2.25.125-61_0711-0720.csv
# E:\课设4\correct_state\冲压\2.26.125-67_0601-0605.csv
# E:\课设4\correct_state\冲压\2.27.125-67_0611-0615.csv
# E:\课设4\correct_state\冲压\2.28.125-67_0621-0625.csv
# E:\课设4\correct_state\冲压\2.29.125-67_0701-0705.csv
# E:\课设4\correct_state\冲压\2.30.125-67_0713-0718.csv
# E:\课设4\correct_state\冲压\2.31.125-67_0721-0725.csv
# E:\课设4\correct_state\冲压\2.32.125-67_0801-0805.csv
# E:\课设4\correct_state\冲压\2.33.125-67_0811-0815.csv
# E:\课设4\correct_state\冲压\2.34.125-67_0821-0825.csv
# E:\课设4\correct_state\冲压\2.35.125-67_0901-0905.csv
# E:\课设4\correct_state\冲压\2.36.125-67_0911-0915.csv
# E:\课设4\correct_state\冲压\2.37.125-67_1015-1020.csv
# E:\课设4\correct_state\切磨端面\7.101.018-34_1010-1015.csv
# E:\课设4\correct_state\切磨端面\7.102.018-34_1017-1022.csv
# E:\课设4\correct_state\切磨端面\7.103.018-34_1024-1029.csv
# E:\课设4\correct_state\切磨端面\7.104.018-34_1102-1107.csv
# E:\课设4\correct_state\切磨端面\7.105.018-34_1108-1114.csv
# E:\课设4\correct_state\切磨端面\7.106.018-34_1121-1126.csv
# E:\课设4\correct_state\切磨端面\7.107.018-34_1126-1202.csv
# E:\课设4\correct_state\切磨端面\7.108.018-49_0701-0705.csv
# E:\课设4\correct_state\切磨端面\7.109.018-49_0711-0715.csv
# E:\课设4\correct_state\切磨端面\7.110.018-49_0721-0725.csv
# E:\课设4\correct_state\切磨端面\7.111.018-49_0801-0805.csv
# E:\课设4\correct_state\切磨端面\7.112.018-49_0811-0815.csv
# E:\课设4\correct_state\切磨端面\7.113.018-49_0821-0825.csv
# E:\课设4\correct_state\加热\4.47.121-206_0501-0510.csv
# E:\课设4\correct_state\加热\4.48.121-206_0511-0520.csv
# E:\课设4\correct_state\加热\4.49.121-206_0521-0530.csv
# E:\课设4\correct_state\加热\4.50.121-206_0601-0610.csv
# E:\课设4\correct_state\加热\4.51.121-206_0711-0720.csv
# E:\课设4\correct_state\加热\4.52.121-206_0721-0730.csv
# E:\课设4\correct_state\加热\4.53.121-206_0911-0920.csv
# E:\课设4\correct_state\加热\4.54.121-206_1011-1020.csv
# E:\课设4\correct_state\加热\4.55.121-230_0601-0605.csv
# E:\课设4\correct_state\加热\4.56.121-230_0611-0615.csv
# E:\课设4\correct_state\加热\4.57.121-230_0621-0625.csv
# E:\课设4\correct_state\加热\4.58.121-230_0701-0705.csv
# E:\课设4\correct_state\加热\4.59.121-230_0711-0715.csv
# E:\课设4\correct_state\加热\4.60.121-230_0721-0725.csv
# E:\课设4\correct_state\加热\4.61.121-230_0801-0805.csv
# E:\课设4\correct_state\加热\4.62.121-230_0811-0815.csv
# E:\课设4\correct_state\加热\4.63.121-230_0821-0825.csv
# E:\课设4\correct_state\加热\4.64.121-230_0901-0905.csv
# E:\课设4\correct_state\加热\4.65.121-230_0911-0915.csv
# E:\课设4\correct_state\加热\4.66.121-230_0921-0925.csv
# E:\课设4\correct_state\加热\4.67.121-230_1005-1010.csv
# E:\课设4\correct_state\加热\4.68.121-230_1011-1016.csv
# E:\课设4\correct_state\加热\4.69.121-230_1024-1030.csv
# E:\课设4\correct_state\加热\4.70.121-230_1101-1107.csv
# E:\课设4\correct_state\半精锥面\1.1.034-389_0611-0616.csv
# E:\课设4\correct_state\半精锥面\1.10.034-389_0914-0919.csv
# E:\课设4\correct_state\半精锥面\1.12.034-389_0920-0925.csv
# E:\课设4\correct_state\半精锥面\1.13.034-389_1015-1020.csv
# E:\课设4\correct_state\半精锥面\1.14.034-389_1025-1030.csv
# E:\课设4\correct_state\半精锥面\1.15.034-389_1101-1106.csv
# E:\课设4\correct_state\半精锥面\1.16.034-389_1107-1112.csv
# E:\课设4\correct_state\半精锥面\1.17.034-389_1113-1118.csv
# E:\课设4\correct_state\半精锥面\1.18.034-389_1121-1126.csv
# E:\课设4\correct_state\半精锥面\1.2.034-389_0617-0622.csv
# E:\课设4\correct_state\半精锥面\1.3.034-389_0628-0704.csv
# E:\课设4\correct_state\半精锥面\1.4.034-389_0704-0709.csv
# E:\课设4\correct_state\半精锥面\1.5.034-389_0711-0716.csv
# E:\课设4\correct_state\半精锥面\1.6.034-389_0721-0726.csv
# E:\课设4\correct_state\半精锥面\1.7.034-389_0727-0802.csv
# E:\课设4\correct_state\半精锥面\1.8.034-389_0802-0807.csv
# E:\课设4\correct_state\半精锥面\1.9.034-389_0825-0830.csv
# E:\课设4\correct_state\摩擦焊\5.71.754-20_0704-0710.csv
# E:\课设4\correct_state\摩擦焊\5.72.754-20_0711-0716.csv
# E:\课设4\correct_state\摩擦焊\5.73.754-20_0721-0726.csv
# E:\课设4\correct_state\摩擦焊\5.74.754-20_0801-0806.csv
# E:\课设4\correct_state\摩擦焊\5.75.754-22_0811-0816.csv
# E:\课设4\correct_state\摩擦焊\5.76.754-22_0821-0826.csv
# E:\课设4\correct_state\摩擦焊\5.77.754-22_0913-0918.csv
# E:\课设4\correct_state\摩擦焊\5.78.754-22_1101-1106.csv
# E:\课设4\correct_state\摩擦焊\5.79.754-35_0801-0806.csv
# E:\课设4\correct_state\摩擦焊\5.80.754-35_0811-0816.csv
# E:\课设4\correct_state\摩擦焊\5.81.754-35_0821-0826.csv
# E:\课设4\correct_state\摩擦焊\5.82.754-35_0901-0906.csv
# E:\课设4\correct_state\摩擦焊\5.83.754-35_0912-0917.csv
# E:\课设4\correct_state\摩擦焊\5.84.754-35_0921-0926.csv
# E:\课设4\correct_state\摩擦焊\5.85.754-35_1011-1016.csv
# E:\课设4\correct_state\摩擦焊\5.86.754-35_1021-1026.csv
# E:\课设4\correct_state\摩擦焊\5.87.754-35_1101-1106.csv
# E:\课设4\correct_state\摩擦焊\5.88.754-35_1111-1116.csv
# E:\课设4\correct_state\摩擦焊\5.89.754-35_1121-1126.csv
# E:\课设4\correct_state\杆部抛光\3.38.K2-5-5_0704-0708.csv
# E:\课设4\correct_state\杆部抛光\3.39.K2-5-5_0721-0725.csv
# E:\课设4\correct_state\杆部抛光\3.40.K2-5-5_0801-0805.csv
# E:\课设4\correct_state\杆部抛光\3.41.K2-5-5_0812-0816.csv
# E:\课设4\correct_state\杆部抛光\3.42.K2-5-5_0822-0826.csv
# E:\课设4\correct_state\杆部抛光\3.43.K2-5-5_0915-0920.csv
# E:\课设4\correct_state\杆部抛光\3.44.K2-5-5_0924-0929.csv
# E:\课设4\correct_state\杆部抛光\3.45.K2-5-5_1011-1015.csv
# E:\课设4\correct_state\杆部抛光\3.46.K2-5-5_1101-1105.csv
# E:\课设4\correct_state\磨锁夹槽\6.100.034-383_1129-1205.csv
# E:\课设4\correct_state\磨锁夹槽\6.90.034-383_0615-0620.csv
# E:\课设4\correct_state\磨锁夹槽\6.91.034-383_0618-0623.csv
# E:\课设4\correct_state\磨锁夹槽\6.92.034-383_0801-0806.csv
# E:\课设4\correct_state\磨锁夹槽\6.93.034-383_0824-0830.csv
# E:\课设4\correct_state\磨锁夹槽\6.94.034-383_0830-0905.csv
# E:\课设4\correct_state\磨锁夹槽\6.95.034-383_0919-0924.csv
# E:\课设4\correct_state\磨锁夹槽\6.96.034-383_0924-0930.csv
# E:\课设4\correct_state\磨锁夹槽\6.97.034-383_1017-1023.csv
# E:\课设4\correct_state\磨锁夹槽\6.98.034-383_1104-1110.csv
# E:\课设4\correct_state\磨锁夹槽\6.99.034-383_1121-1127.csv
